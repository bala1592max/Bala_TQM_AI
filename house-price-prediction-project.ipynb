# %% [markdown]
# <a href="https://www.kaggle.com/code/balasubramaniang/house-price-prediction-project?scriptVersionId=319862200" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import os
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/competitions/home-data-for-ml-course/sample_submission.csv
# /kaggle/input/competitions/home-data-for-ml-course/sample_submission.csv.gz
# /kaggle/input/competitions/home-data-for-ml-course/train.csv.gz
# /kaggle/input/competitions/home-data-for-ml-course/data_description.txt
# /kaggle/input/competitions/home-data-for-ml-course/test.csv.gz
# /kaggle/input/competitions/home-data-for-ml-course/train.csv
# /kaggle/input/competitions/home-data-for-ml-course/test.csv

# %%
df=pd.read_csv('/kaggle/input/competitions/home-data-for-ml-course/train.csv')
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
null_cols=df.isnull().sum()
null_cols[null_cols>0]
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType       872
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %%
df=df.drop(columns=['Alley','PoolQC','Fence','MiscFeature'])

# %%
null_cols=df.isnull().sum()
null_cols[null_cols>0]
# Out:
# LotFrontage     259
# MasVnrType      872
# MasVnrArea        8
# BsmtQual         37
# BsmtCond         37
# BsmtExposure     38
# BsmtFinType1     37
# BsmtFinType2     38
# Electrical        1
# FireplaceQu     690
# GarageType       81
# GarageYrBlt      81
# GarageFinish     81
# GarageQual       81
# GarageCond       81
# dtype: int64

# %%
df['LotFrontage']=df['LotFrontage'].fillna(df['LotFrontage'].median())
df['FireplaceQu']=df['FireplaceQu'].fillna('None')

# %%
null_cols=df.isnull().sum()
null_cols[null_cols>0]
# Out:
# MasVnrType      872
# MasVnrArea        8
# BsmtQual         37
# BsmtCond         37
# BsmtExposure     38
# BsmtFinType1     37
# BsmtFinType2     38
# Electrical        1
# GarageType       81
# GarageYrBlt      81
# GarageFinish     81
# GarageQual       81
# GarageCond       81
# dtype: int64

# %%
cols=['MasVnrArea','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2','Electrical','GarageType','GarageYrBlt','GarageFinish','GarageQual','GarageCond']
df[cols].dtypes
# Out:
# MasVnrArea      float64
# BsmtQual         object
# BsmtCond         object
# BsmtExposure     object
# BsmtFinType1     object
# BsmtFinType2     object
# Electrical       object
# GarageType       object
# GarageYrBlt     float64
# GarageFinish     object
# GarageQual       object
# GarageCond       object
# dtype: object

# %%
cat_cols = ['BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2','Electrical','GarageType','GarageFinish','GarageQual','GarageCond']
for col in cat_cols:
    df[col] = df[col].fillna('None')
df['MasVnrArea']=df['MasVnrArea'].fillna(df['MasVnrArea'].median())
df['GarageYrBlt']=df['GarageYrBlt'].fillna(df['GarageYrBlt'].median())

# %%
null_cols=df.isnull().sum()
null_cols[null_cols>0]
# Out:
# MasVnrType    872
# dtype: int64

# %%
df.drop(columns=['BsmtQual'])
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0        1          60       RL         65.0     8450   Pave      Reg
# 1        2          20       RL         80.0     9600   Pave      Reg
# 2        3          60       RL         68.0    11250   Pave      IR1
# 3        4          70       RL         60.0     9550   Pave      IR1
# 4        5          60       RL         84.0    14260   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave      Reg
# 1456  1457          20       RL         85.0    13175   Pave      Reg
# 1457  1458          70       RL         66.0     9042   Pave      Reg
# 1458  1459          20       RL         68.0     9717   Pave      Reg
# 1459  1460          20       RL         75.0     9937   Pave      Reg
#
#      LandContour Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# ...

# %%
cat_cols=df.select_dtypes(include=['object']).columns
cat_cols
# Out:
# Index(['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
df_encoded=pd.get_dummies(df,columns=cat_cols)
df_encoded
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1455  1456          60         62.0     7917            6            5
# 1456  1457          20         85.0    13175            6            6
# 1457  1458          70         66.0     9042            7            9
# 1458  1459          20         68.0     9717            5            6
# 1459  1460          20         75.0     9937            5            6
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  SaleType_ConLw  \
# ...

# %%
df_encoded['KitchenQual_Ex'].unique()
# Out:
# array([False,  True])

# %%
bool_cols=df.select_dtypes(include=['bool']).columns
bool_cols
# Out:
# Index([], dtype='object')

# %%
df_encoded.dtypes
# Out:
# Id                         int64
# MSSubClass                 int64
# LotFrontage              float64
# LotArea                    int64
# OverallQual                int64
#                           ...
# SaleCondition_AdjLand       bool
# SaleCondition_Alloca        bool
# SaleCondition_Family        bool
# SaleCondition_Normal        bool
# SaleCondition_Partial       bool
# Length: 287, dtype: object

# %%
# Calculate the correlation for all numerical columns
corr_matrix = df_encoded.corr()

# Isolate SalePrice and sort to find the strongest predictors
top_features=corr_matrix['SalePrice'].sort_values(ascending=False).head(15)
top_features_names=corr_matrix['SalePrice'].sort_values(ascending=False).head(15).index
top_features
# Out:
# SalePrice           1.000000
# OverallQual         0.790982
# GrLivArea           0.708624
# GarageCars          0.640409
# GarageArea          0.623431
# TotalBsmtSF         0.613581
# 1stFlrSF            0.605852
# FullBath            0.560664
# BsmtQual_Ex         0.553105
# TotRmsAbvGrd        0.533723
# YearBuilt           0.522897
# YearRemodAdd        0.507101
# KitchenQual_Ex      0.504094
# Foundation_PConc    0.497734
# MasVnrArea          0.472614
# Name: SalePrice, dtype: float64

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(df_encoded[top_features_names].corr(), annot=True, cmap='coolwarm', fmt=".2f", square=True)
plt.title('Correlation Heatmap (Top 10 Features with SalePrice)', fontsize=14)
plt.tight_layout()
plt.show()

# %%
df_test=pd.read_csv('/kaggle/input/competitions/home-data-for-ml-course/test.csv')
df_test
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
features=['OverallQual','GrLivArea','GarageArea','TotalBsmtSF',
'1stFlrSF']
x=df_encoded[features]
y=df_encoded['SalePrice']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#       OverallQual  GrLivArea  GarageArea  TotalBsmtSF  1stFlrSF
# 254             5       1314         294         1314      1314
# 1066            6       1571         380          799       799
# 638             5        796           0          796       796
# 799             5       1768         240          731       981
# 380             5       1691         308         1026      1026
# ...           ...        ...         ...          ...       ...
# 1095            6       1314         440         1314      1314
# 1130            4       1981         576         1122      1328
# 1294            5        864         572          864       864
# 860             7       1426         216          912       912
# 1126            7       1555         660         1373      1555
#
# [1168 rows x 5 columns]

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
y_pred_train=model.predict(x_train)

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
rmse=np.sqrt(mean_squared_error(y_train,y_pred_train))
r2=r2_score(y_train,y_pred_train)
print(f"RMSE train: {rmse:,.2f}")
print(f"R2 train: {r2:,.2f}")
# Out:
# RMSE train: 38,927.88
# R2 train: 0.75

# %%
rmse=np.sqrt(mean_squared_error(y_test,y_pred))
r2=r2_score(y_test,y_pred)
print(f"RMSE test: {rmse:,.2f}")
print(f"R2 test: {r2:,.2f}")
# Out:
# RMSE test: 39,969.98
# R2 test: 0.79

# %%
df_test1=pd.read_csv('/kaggle/input/competitions/home-data-for-ml-course/test.csv')
df_test1.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
df_test1.rename(columns={'KitchenQual':'KitchenQual_Ex'},inplace=True)
df_test1.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual_Ex',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
features_test=['OverallQual','GrLivArea','GarageArea','TotalBsmtSF',
'1stFlrSF']

# %%
df_test1=df_test1[features_test]

# %%
df_test1
# Out:
#       OverallQual  GrLivArea  GarageArea  TotalBsmtSF  1stFlrSF
# 0               5        896       730.0        882.0       896
# 1               6       1329       312.0       1329.0      1329
# 2               5       1629       482.0        928.0       928
# 3               6       1604       470.0        926.0       926
# 4               8       1280       506.0       1280.0      1280
# ...           ...        ...         ...          ...       ...
# 1454            4       1092         0.0        546.0       546
# 1455            4       1092       286.0        546.0       546
# 1456            5       1224       576.0       1224.0      1224
# 1457            5        970         0.0        912.0       970
# 1458            7       2000       650.0        996.0       996
#
# [1459 rows x 5 columns]

# %%
df_test1=df_test1.fillna(0)
df_test1.isnull().sum()
# Out:
# OverallQual    0
# GrLivArea      0
# GarageArea     0
# TotalBsmtSF    0
# 1stFlrSF       0
# dtype: int64

# %%
final_pred=model.predict(df_test1)
final_pred
# Out:
# array([135945.29399983, 167330.39199476, 151960.31491646, ...,
#        150117.59608616,  96685.02843233, 230230.07207159])

# %%
# 1. Re-import the fresh test data to get the 'Id' column back
df_test_raw = pd.read_csv('/kaggle/input/competitions/home-data-for-ml-course/test.csv')

# %%
submission = pd.DataFrame({
    'Id': df_test_raw['Id'],
    'SalePrice': final_pred})

# %%
submission.to_csv('submission.csv', index=False)

# %%
plt.figure(figsize=(8, 6))

# Plot the scatter points and the regression line
sns.regplot(x=y_test, y=y_pred, 
            scatter_kws={'alpha': 0.5, 'color': 'blue'}, 
            line_kws={'color': 'red', 'linewidth': 2, 'label': 'Regression Line'})

plt.title('Predicted vs Actual House Prices (Test Data)', fontsize=14)
plt.xlabel('Actual SalePrice', fontsize=12)
plt.ylabel('Predicted SalePrice', fontsize=12)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
